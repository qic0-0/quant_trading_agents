# %%
# !python run_experiment1.py --output results/experiment1_results
# Out:
# 2025-12-08 22:24:15,787 - __main__ - INFO - Experiment results will be saved to: results/experiment1_results
# 2025-12-08 22:24:15,788 - __main__ - INFO - ======================================================================
# 2025-12-08 22:24:15,788 - __main__ - INFO - EXPERIMENT 1: Experiment 1: Main System Comparison
# 2025-12-08 22:24:15,788 - __main__ - INFO - ======================================================================
# 2025-12-08 22:24:15,788 - __main__ - INFO - Period: 2023-01-01 to 2024-12-01
# 2025-12-08 22:24:15,788 - __main__ - INFO - Initial Cash: $100,000.00
# 2025-12-08 22:24:15,788 - __main__ - INFO - Stocks: 3 | Modes: ['full', 'quant_only', 'llm_only'] | Model Types: ['hmm', 'xgboost']
# 2025-12-08 22:24:15,788 - __main__ - INFO - Total Backtests: 15
# 2025-12-08 22:24:15,788 - __main__ - INFO - ======================================================================
# 2025-12-08 22:24:15,788 - __main__ - INFO -
# --- Category: INCREASING ---
# 2025-12-08 22:24:15,788 - __main__ - INFO -
# [1/15] NVDA - full - hmm
# 2025-12-08 22:24:15,788 - __main__ - INFO - Running: NVDA | Mode: full | Model: hmm | Category: increasing
# 2025-12-08 22:24:16,250 - llm.llm_client - INFO - Using Argonne access token
# 2025-12-08 22:24:16,278 - llm.llm_client - INFO - LLM client initialized with base URL: https://inference-api.alcf.anl.gov/resource_server/sophia/vllm/v1
# 2025-12-08 22:24:16,278 - DataAgent - INFO - Registered tool: fetch_price_data
# 2025-12-08 22:24:16,278 - DataAgent - INFO - Registered tool: fetch_fundamentals
# 2025-12-08 22:24:16,278 - DataAgent - INFO - Registered tool: fetch_news
# 2025-12-08 22:24:16,278 - DataAgent - INFO - Registered tool: fetch_economic_indicators
# 2025-12-08 22:24:16,278 - FeatureEngineeringAgent - INFO - Registered tool: compute_technical_indicators
# 2025-12-08 22:24:16,278 - FeatureEngineeringAgent - INFO - Registered tool: compute_factors
# 2025-12-08 22:24:16,278 - FeatureEngineeringAgent - INFO - Registered tool: embed_text
# 2025-12-08 22:24:16,278 - FeatureEngineeringAgent - INFO - Registered tool: store_embedding
# 2025-12-08 22:24:16,278 - FeatureEngineeringAgent - INFO - Registered tool: retrieve_similar_news
# 2025-12-08 22:24:16,278 - QuantModelingAgent - INFO - Registered tool: read_document
# 2025-12-08 22:24:16,278 - QuantModelingAgent - INFO - Registered tool: execute_python
# 2025-12-08 22:24:16,278 - MarketSenseAgent - INFO - Registered tool: retrieve_knowledge
# 2025-12-08 22:24:16,278 - MarketSenseAgent - INFO - Registered tool: retrieve_historical_events
# 2025-12-08 22:24:16,278 - CoordinatorAgent - INFO - Registered tool: get_portfolio_state
# 2025-12-08 22:24:16,278 - CoordinatorAgent - INFO - Registered tool: validate_trade
# 2025-12-08 22:24:16,278 - CoordinatorAgent - INFO - Registered tool: execute_trade
# 2025-12-08 22:24:16,278 - CoordinatorAgent - INFO - Registered tool: calculate_position_size
# 2025-12-08 22:24:16,278 - main - INFO - Trading system initialized
# 2025-12-08 22:24:16,278 - main - INFO - Running backtest from 2023-01-01 to 2024-12-01 [MODE: full]
# 2025-12-08 22:24:16,278 - main - INFO - Tickers: ['NVDA']
# 2025-12-08 22:24:16,278 - main - INFO - Collecting historical data...
# 2025-12-08 22:24:16,714 - agents.data_agent - INFO - Fetched 481 days of price data for NVDA
# 2025-12-08 22:24:16,957 - agents.data_agent - INFO - Fetched fundamentals for NVDA
# 2025-12-08 22:24:16,958 - main - INFO - Backtesting NVDA: 97 trading periods
# 2025-12-08 22:24:16,958 - agents.quant_model_agent - INFO - Training hmm model for NVDA...
# 2025-12-08 22
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 11.93it/s]
# 2025-12-08 23:20:31,845 - agents.market_sense_agent - INFO - Retrieved 3 knowledge chunks for query: MRNA market conditions ...
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 72.91it/s]
# 2025-12-08 23:20:31,860 - agents.market_sense_agent - INFO - Retrieved 2 historical events
# ^C
# Traceback (most recent call last):
#   File "/Users/zero/Desktop/CMSC35370/final project/quant_trading_agents/run_experiment1.py", line 628, in <module>
#     main()
#   File "/Users/zero/Desktop/CMSC35370/final project/quant_trading_agents/run_experiment1.py", line 620, in main
#     runner.run_all(
#   File "/Users/zero/Desktop/CMSC35370/final project/quant_trading_agents/run_experiment1.py", line 412, in run_all
#     result = self.run_single_backtest(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zero/Desktop/CMSC35370/final project/quant_trading_agents/run_experiment1.py", line 288, in run_single_backtest
#     result = system.run_backtest(
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zero/Desktop/CMSC35370/final project/quant_trading_agents/main.py", line 302, in run_backtest
#     market_result = self.market_sense_agent.run({
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zero/Desktop/CMSC35370/final project/quant_trading_agents/agents/market_sense_agent.py", line 211, in run
#     response = self.llm_client.chat(messages, temperature=0.3)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/zero/Desktop/CMSC35370/final project/quant_trading_agents/llm/llm_client.py", line 137, in chat
#     response = self.client.chat.completions.create(**kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/openai/_utils/_utils.py", line 286, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/openai/resources/chat/completions/completions.py", line 1189, in create
#     return self._post(
#            ^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/openai/_base_client.py", line 1259, in post
#     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/openai/_base_client.py", line 982, in request
#     response = self._client.send(
#                ^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_client.py", line 1014, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpx/_transports/default.py", line 250, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py", line 256, in handle_request
#     raise exc from None
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection_pool.py", line 236, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/connection.py", line 103, in handle_request
#     return self._connection.handle_request(request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py", line 136, in handle_request
#     raise exc
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py", line 106, in handle_request
#     ) = self._receive_response_headers(**kwargs)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py", line 177, in _receive_response_headers
#     event = self._receive_event(timeout=timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_sync/http11.py", line 217, in _receive_event
#     data = self._network_stream.read(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/site-packages/httpcore/_backends/sync.py", line 128, in read
#     return self._sock.recv(max_bytes)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/ssl.py", line 1233, in recv
#     return self.read(buflen)
#            ^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.12/ssl.py", line 1106, in read
#     return self._sslobj.read(len)
#            ^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python run_experiment2.py --output results/experiment2_results

# %%
# Plot all results from experiment 1
python plot_trades.py --results results/experiment1_results --output plots/exp1

# Plot all results from experiment 2
python plot_trades.py --results results/experiment2_results --output plots/exp2

# Plot only NVDA
python plot_trades.py --results results/experiment1_results --ticker NVDA

# Plot specific configuration
python plot_trades.py --results results/experiment1_results --ticker NVDA --mode full --model hmm

# Create comparison subplot (all configs for each ticker in one figure)
python plot_trades.py --results results/experiment1_results --comparison
```

**Features:**
- **Red ▲** = BUY points
- **Blue ▼** = SELL points
- 2-year date range with proper month labels (every 2 months)
- Shows metrics (Return, Sharpe) in title
- Trade count annotation box
- `--comparison` mode creates a grid showing all 5 configurations side-by-side

**Output files:**
```
plots/exp1/
├── NVDA_full_hmm_trades.png
├── NVDA_full_xgboost_trades.png
├── NVDA_quant_only_hmm_trades.png
├── NVDA_quant_only_xgboost_trades.png
├── NVDA_llm_only_none_trades.png
├── NVDA_comparison.png  (if --comparison)
├── MRNA_...
└── KO_...

# %%
# First run experiment 5 to collect responses
python run_experiment5.py --output results/experiment5_results

# Then evaluate responses with LLM
python evaluate_experiment5.py --results results/experiment5_results
```

**What it does:**
1. Loads Q&A pairs from `experiment5_responses_*.json`
2. Sends each Q&A to Claude API with evaluation criteria
3. Parses scores (1-5 for each of 5 criteria)
4. Saves results incrementally (safe if crashes)

**Output files:**
```
results/experiment5_results/
├── experiment5_evaluation_<timestamp>.json   # Raw scores
├── experiment5_evaluation_<timestamp>.csv    # Spreadsheet format
└── experiment5_evaluation_<timestamp>.md     # Full report
